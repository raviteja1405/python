# %%
# import pandas as pd
# file_path="C:\\Users\\DELL\\Downloads\\World_development_mesurement.xlsx"
# df1=pd.read_excel(file_path)
#df.fillna(df.median(), inplace=True)
# print(df1)

# %%
# Data Loading and Preprocessing:
import pandas as pd
file_path ="C:\\Users\\DELL\\Downloads\\sales_data_sample.csv"
df = pd.read_csv(file_path,encoding='Windows-1252')
df['ADDRESSLINE2'].fillna(method='bfill', inplace=True)
df['ADDRESSLINE2'].fillna(method='ffill',inplace=True)
df['STATE'].fillna(method='ffill',inplace=True)
df['POSTALCODE'].fillna(method='ffill',inplace=True)
df['TERRITORY'].fillna(method='ffill',inplace=True)
df['TERRITORY'].fillna(method='bfill',inplace=True)
print(df)
print(df.to_csv(cleaned_sales_data.csv,index=False))
# Q1=df['PRICEEACH'].quantile(0.25)
# Q3=df['PRICEEACH'].quantile(0.75)
# IQR=Q1-Q3
# print(Q1,Q3)
# print(IQR)
# lower_bound=Q1-1.5*IQR
# upper_bound=Q3+1.5*IQR
# print(lower_bound,upper_bound)
# aggregated_data = df.groupby(['DEALSIZE','COUNTRY'])['SALES'].sum()
# print(aggregated_data)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0      2/24/2003   Shipped       1         2     2003  ...
# 1       5/7/2003   Shipped       2         5     2003  ...
# 2       7/1/2003   Shipped       3         7     2003  ...
# 3      8/25/2003   Shipped       3         8     2003  ...
# 4     10/10/2003   Shipped       4        10     2003  ...
# ...          ...       ...     ...       ...      ...  ...
# 2818   12/2/2004   Shipped       4        12     2004  ...
# 2819   1/31/2005   Shipped       1         1     2005  ...
# 2820    3/1/2005  Resolved       1         3     2005  ...
# 2821   3/28/2005   Shipped       1         3     2005  ...
# 2822    5/6/2005   On Hold       2         5     2005  ...
#
#                        ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0           897 Long Airport Avenue       Level 3            NYC    NY
# 1                59 rue de l'Abbaye       Level 3          Reims    NY
# 2     27 rue du Colonel Pierre Avia       Level 3          Paris    NY
# 3                78934 Hillside Dr.       Level 3       Pasadena    CA
# 4                   7734 Strong St.       Level 3  San Francisco    CA
# ...                             ...           ...            ...   ...
# 2818             C/ Moralzarzal, 86     Suite 750         Madrid    NY
# 2819                    Torikatu 38     Suite 750           Oulu    NY
# 2820             C/ Moralzarzal, 86     Suite 750         Madrid    NY
# 2821          1 rue Alsace-Lorraine     Suite 750       Toulouse    NY
# 2822             8616 Spinnaker Dr.     Suite 750         Boston    MA
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         10022      USA      EMEA              Yu             Kwai    Small
# 1         51100   France      EMEA         Henriot             Paul    Small
# 2         75508   France      EMEA        Da Cunha           Daniel   Medium
# 3         90003      USA      EMEA           Young            Julie   Medium
# 4         90003      USA      EMEA           Brown            Julie   Medium
# ...         ...      ...       ...             ...              ...      ...
# 2818      28034    Spain      EMEA          Freyre            Diego    Small
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 2820      28034    Spain      EMEA          Freyre            Diego   Medium
# 2821      31000   France      EMEA          Roulet          Annette    Small
# 2822      51003      USA      EMEA         Yoshido             Juri   Medium
#
# [2823 rows x 25 columns]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10812\2675336421.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ADDRESSLINE2'].fillna(method='bfill', inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10812\2675336421.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['ADDRESSLINE2'].fillna(method='bfill', inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10812\2675336421.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['ADDRESSLINE2'].fillna(method='ffill',inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10812\2675336421.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['STATE'].fillna(method='ffill',inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10812\2675336421.py:7: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['STATE'].fillna(method='ffill',inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10812\2675336421.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['POSTALCODE'].fillna(method='ffill',inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10812\2675336421.py:8: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['POSTALCODE'].fillna(method='ffill',inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10812\2675336421.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TERRITORY'].fillna(method='ffill',inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10812\2675336421.py:9: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['TERRITORY'].fillna(method='ffill',inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10812\2675336421.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['TERRITORY'].fillna(method='bfill',inplace=True)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 12
#      10 df['TERRITORY'].fillna(method='bfill',inplace=True)
#      11 print(df)
# ---> 12 print(df.to_csv(cleaned_sales_data.csv,index=False))
#
# NameError: name 'cleaned_sales_data' is not defined

# %%
# Data Analysis:
import pandas as pd
# mean_data=df.groupby(['DEALSIZE','COUNTRY'])['SALES'].mean()
# print(mean_data)

# median_data=df.groupby(['DEALSIZE','COUNTRY'])['SALES'].median()
# print(median_data)

# st_d=df.groupby(['DEALSIZE','COUNTRY'])['SALES'].std()
# print(st_d)

top_performer=df.groupby(['DEALSIZE','COUNTRY'])['SALES'].sum()
print(top_performer)
print("*****")
print(top_performer.max())
# Out:
# DEALSIZE  COUNTRY
# Large     Australia        60252.04
#           Austria          32792.08
#           Canada            9064.89
#           Denmark          49886.67
#           Finland          40012.32
#           France          179004.87
#           Germany          30496.06
#           Ireland          15439.44
#           Italy            57565.43
#           Japan            25470.16
#           Norway           41042.70
#           Philippines       7483.98
#           Singapore        35363.19
#           Spain           141042.51
#           Sweden           14345.30
#           UK               35155.24
#           USA             527702.38
# Medium    Australia       381245.00
#           Austria         125314.10
#           Belgium          71531.37
#           Canada          137430.48
#           Denmark         140050.70
#           Finland         201741.96
#           France          643606.22
#           Germany         133151.79
#           Ireland          26822.87
#           Italy           184133.88
#           Japan           101097.22
#           Norway          190502.23
#           Philippines      62415.84
#           Singapore       178562.94
#           Spain           757927.09
#           Sweden          143685.97
#           Switzerland      98617.40
#           UK              301233.02
#           USA            2208362.16
# Small     Australia       189126.06
#           Austria          43956.35
#           Belgium          36881.25
#           Canada           77583.19
#           Denmark          55699.78
#           Finland          87827.63
#           France          288305.43
#           Germany          56824.24
#           Ireland          15494.12
#           Italy           132975.00
#           Japan            61600.43
#           Norway           75918.77
#           Philippines      24115.91
#           Singapore        74562.28
#           Spain           316717.32
#           Sweden           51982.94
#           Switzerland      19096.16
#           UK              142492.20
#           USA             891918.29
# Name: SALES, dtype: float64
# *****
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 5
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5916\1996169656.py in ?()
#      11
#      12 top_performer=df.groupby(['DEALSIZE','COUNTRY'])['SALES'].sum()
#      13 print(top_performer)
#      14 print("*****")
# ---> 15 print(top_performer.max(5))
#
# ~\anaconda3\Lib\site-packages\pandas\core\series.py in ?(self, axis, skipna, numeric_only, **kwargs)
#    6513         skipna: bool = True,
#    6514         numeric_only: bool = False,
#    6515         **kwargs,
#    6516     ):
# -> 6517         return NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, axis, skipna, numeric_only, **kwargs)
#   12400         skipna: bool_t = True,
#   12401         numeric_only: bool_t = False,
#   12402         **kwargs,
#   12403     ):
# > 12404         return self._stat_function(
#   12405             "max",
#   12406             nanops.nanmax,
#   12407             axis,
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373         nv.validate_func(name, (), kwargs)
#   12374
#   12375         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379         )
#
# ~\anaconda3\Lib\site-packages\pandas\core\series.py in ?(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6435         """
#    6436         delegate = self._values
#    6437
#    6438         if axis is not None:
# -> 6439             self._get_axis_number(axis)
#    6440
#    6441         if isinstance(delegate, ExtensionArray):
#    6442             # dispatch to ExtensionArray interface
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     574     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     575         try:
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named 5 for object type Series

# %%
# Visualization
import matplotlib.pyplot as plt
# plt.plot(df['SALES'],df['COUNTRY'],linestyle='-')
# plt.xlabel("SALES")
# plt.ylabel("COUNTRY")
# plt.show()

plt.scatter(df['SALES'],df['QUANTITYORDERED'])
plt.xlabel("SALES")
plt.ylabel("QUANTITY")
plt.show()
